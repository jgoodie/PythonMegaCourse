# %%
import pandas

# %%
df = pandas.read_csv("/Users/jgoodman/Documents/HCP Anywhere/HCP-Citi/Everspan_COSBench_4wrkrs.csv")
df
# Out:
#    Timestamp Op-Count  Byte-Count Avg-ResTime Avg-ProcTime Throughput  \
# 0        NaN    write       write       write        write      write
# 1   15:32:42        0           0         NaN          NaN          0
# 2   15:32:47        0           0         NaN          NaN          0
# 3   15:32:52        0           0         NaN          NaN          0
# 4   15:32:57        0           0         NaN          NaN          0
# 5   15:33:02        0           0         NaN          NaN          0
# 6   15:33:07        1  3000000000       28256        16719       0.18
# 7   15:33:12        0           0         NaN          NaN          0
# 8   15:33:17        1  3000000000       38786        26755       0.18
# 9   15:33:22        0           0         NaN          NaN          0
# 10  15:33:27        0           0         NaN          NaN          0
# 11  15:33:32        1  3000000000       52208        40597       0.19
# ...
